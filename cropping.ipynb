# %%
from skimage import io, morphology, color, util, filters, draw
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", palette="Set2")

data = "data/"

# %%
img  = io.imread(data + '10_fluorescence_chsC.jpg')
img_true  = io.imread(data + '10_brightfield_chsC.jpg')

img.shape
# Out:
# (2048, 2048, 3)

# %%
io.imshow(img)

# %%
dims = [0,1150,500,1600]
io.imshow(img[dims[0]:dims[1], dims[2]:dims[3]])

# %%
io.imshow(img_true[dims[0]:dims[1], dims[2]:dims[3]])

# %%
io.imsave(data+"10a_fluorescence_chsC.png", img[dims[0]:dims[1], dims[2]:dims[3]], plugin="pil")
io.imsave(data+"10a_brightfield_chsC.png", img_true[dims[0]:dims[1], dims[2]:dims[3]], plugin="pil")
# Out:
# <ipython-input-81-9bb898315b09>:1: UserWarning: data/10a_fluorescence_chsC.png is a low contrast image
#   io.imsave(data+"10a_fluorescence_chsC.png", img[dims[0]:dims[1], dims[2]:dims[3]], plugin="pil")
